# %%
# colab : linux -> ubuntu 22.04 lst ver
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy

# %%
# 프로젝트 차별성이 있으면 매우 좋다
import pandas as pd     # pandas 2.0 이후 버전은 (numpy, Arrow(<-속도가 더 빠르다)), 쓰는 방식은 같음
print(pd.__version__)
# Out:
# 1.5.3

# %%
import numpy as np
a=np.array([[3,7,5],[8,4,3],[2,4,9]])
print(a)
print("범위:",np.ptp(a))        # 최대값과 최소값의 차
print("행범위",np.ptp(a,axis=1))        #(열방향 (행범위))방향
print("1사 분위수",np.percentile(a,25)) #100 25:1사분위, 50:중위, 75:3사분위
print("행 중위수",np.median(a,axis=0))
print("열 평균", np.mean(a,axis=1))
print("전체 분산"),np.var(a)
print("전체표준편차",np.std(a))
# Out:
# [[3 7 5]
#  [8 4 3]
#  [2 4 9]]
# 범위: 7
# 행범위 [4 5 7]
# 1사 분위수 3.0
# 행 중위수 [3. 4. 5.]
# 열 평균 [5. 5. 5.]
# 전체 분산
# 전체표준편차 2.309401076758503

# %%
int_type=['uint8','int8','int16']   # usigned
for int_type in int_type:
    print(np.iinfo(int_type))
# Out:
# Machine parameters for uint8
# ---------------------------------------------------------------
# min = 0
# max = 255
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------

# %%
# Series(열), Data Frame
# 열중심 (위 아래로 출력)
import pandas as pd
data=pd.Series([0.25,0.5,0.75,1.0],
               index=['a','b','c','d'])  # 행이름 : index
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['b']       # 인덱스 이름으로
# Out:
# 0.5

# %%
data[1]         # 번호로 접근,Rangeindex 는 자동으로 설정
# Out:
# 0.5

# %%
# ndarray  + dict 로 구성
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
(data.items())      # dict의 명령어가 Series 에서도 작용가능

# %%
data['e']=1.25  # 실시간 추가도 가능
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# e    1.25
# dtype: float64

# %%
data['a':'c']  # 키는 마지막 생략안됨
# Out:
# a    0.25
# b    0.50
# c    0.75
# dtype: float64

# %%
data[0:2]   # 숫자 인덱스는 뒤에 생략
# Out:
# a    0.25
# b    0.50
# dtype: float64

# %%
data[['a','e']]
# Out:
# a    0.25
# e    1.25
# dtype: float64

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})

# %%
data=pd.DataFrame({'area':area,'pop':pop})
data
# 시리즈의 키 는 행이름
# 데이터프레임의 키는 열이름
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['area'] # numpy에서는 행의 의미
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
data.area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
# 파생변수
data['density']=data['pop']/data['area']
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
data.values
# Out:
# array([[4.23967000e+05, 3.83325210e+07, 9.04139261e+01],
#        [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#        [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#        [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#        [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]])

# %%
data.keys()  # index가 발달된 pandas    @문자열은 object 로 인식
# Out:
# Index(['area', 'pop', 'density'], dtype='object')

# %%
data.T  # 전치
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
data.values[0]  # 행의 의미
# Out:
# array([4.23967000e+05, 3.83325210e+07, 9.04139261e+01])

# %%
data.iloc[:3,:2]    # 012,01    번호는 끝 미포함 출력
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127

# %%
data.loc[:'Illinois',:'pop']    # 키는 포함해서 출력
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data.iloc[:3,:'pop']    #섞어 쓰면 에러!

# %%
# 문제)
# density>100 큰 'pop','density'열을 출력하시요
# density의 California 의 데이터를 90으로 수정하시오
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
data.loc[data.density>100,['pop','density']]
data.loc['Califonia','density']=90
data
# Out:
#                 area         pop     density
# California  423967.0  38332521.0   90.413926
# Texas       695662.0  26448193.0   38.018740
# New York    141297.0  19651127.0  139.076746
# Florida     170312.0  19552860.0  114.806121
# Illinois    149995.0  12882135.0   85.883763
# Califonia        NaN         NaN   90.000000

# %%
s=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])
print(s)
s.reindex(['e','b','f','d'])    # index 순서 조정
# 없는 data = NaN
# Out:
# a    0.517283
# b    0.458596
# c    1.603781
# d   -0.330864
# e   -1.289136
# dtype: float64
# e   -1.289136
# b    0.458596
# f         NaN
# d   -0.330864
# dtype: float64

# %%
# numpy 처럼 작동
ps=pd.Series(100,index=[10,11,12])  #default int 64
print(ps)
type(ps)
# 값이 하나인데 인덱스가 3개  <= 브로드캐스팅
# Out:
# 10    100
# 11    100
# 12    100
# dtype: int64
# pandas.core.series.Series

# %%
print(ps.dtype) #@!!!!!!!!!!! 중요
print(ps.shape) #@!!!!!!!!!!! 중요
print(ps.ndim)
print(ps.size)
# ndarray, dict 명령어 둘 다 가능!
# Out:
# int64
# (3,)
# 1
# 3

# %%
import pandas as pd
import numpy as np

# list =>ndarray -> series
data = np.array(['a', 'b', 'c', 'd', 'a'])
s = pd.Series(data)
print("시리즈 데이터", s.values)
print('\n')
print("시리즈 인덱스", s.index) # Rangeindex
# start: 시작 값 (0)
# stop: 종료 값 (5, 포함되지 않음)
# step: 증가 간격 (1)
print('\n')
print("시리즈 초기화", s)
print('\n')
print("시리즈 인덱스의 값",s.index.values)  # index 자체도 dict
print(s[0])
print('\n')
print(s.head())
print('밸류') # 밸류(값)의 수
print(s.value_counts())     # 키 별로 도수 분표
print('\n')
print(s.value_counts(normalize=True))  # 상대도수분표
print('\n')
print(s.describe()) # count, unique, top, freq
# count: 데이터의 총 수, unique: 고유한 값의 수, top:가장 자주 등장하는 값, freq : 가장자주 등장하는 값의 빈도수
print('\n')
print("데이터의 타입:",s.dtypes)
print('\n')
print("차원",s.ndim)
print('\n')
print("차수",s.shape)
# Out:
# 시리즈 데이터 ['a' 'b' 'c' 'd' 'a']
#
#
# 시리즈 인덱스 RangeIndex(start=0, stop=5, step=1)
#
#
# 시리즈 초기화 0    a
# 1    b
# 2    c
# 3    d
# 4    a
# dtype: object
#
#
# 시리즈 인덱스의 값 [0 1 2 3 4]
# a
#
#
# 0    a
# 1    b
# 2    c
# 3    d
# 4    a
# dtype: object
# 밸류
# a    2
# b    1
# c    1
# d    1
# dtype: int64
#
#
# a    0.4
# b    0.2
# c    0.2
# d    0.2
# dtype: float64
#
#
# count     5
# unique    4
# top       a
# freq      2
# dtype: object
#
#
# 데이터의 타입: object
#
#
# 차원 1
#
#
# 차수 (5,)

# %%
# 인덱스와 요소연산
sdata={'Ohio':35000,'Texas':71000,'Oregon':16000,'Utah':5000}
obj3=pd.Series(sdata)
print(obj3)
states=['California','Ohio','Oregon','Texas']   # 인덱스로 부여
obj4=pd.Series(sdata,index=states)
print('\n')
print(obj4)
print('\n')
print("null 값이 있는가? ", pd.isnull(obj4))    #null = T
print("결측치가 있는가?",pd.notnull(obj4))      #notnull=T
print("연산결과 출력 : ",obj3+obj4)             #키는 연산에 모두 참여, 하나라도 NaN가 있으면 결과도 NaN
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
#
#
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64
#
#
# null 값이 있는가?  California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool
# 결측치가 있는가? California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool
# 연산결과 출력 :  California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
print(s)
s=pd.Series(['A','B','Aaba'])
s.str.count('a')    # 벡터화 연산 : 고속으로 문자열 처리
# 문자열 함수 : find, replace, count, upper, lower, ..
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    a
# dtype: object
# 0    0
# 1    0
# 2    2
# dtype: int64

# %%
# scikits:ML module
from sklearn.datasets import load_iris
iris=load_iris()
type(iris)  #Bunch
# Out:
# sklearn.utils._bunch.Bunch

# %%
# R 처럼
# 독립변수 : data
# 종속변수 : target
# 열 이름 : feature_names
iris

# %%
# column 으로합침
# 행이름 : index
# 열이름 : columns
iris=pd.DataFrame(data=np.c_[iris['data'],iris['target']],  # c_ =>cbind
                  columns=iris['feature_names']+['target'])

# %%
iris.info()     # index 정보, 컬럼정보, 데이터 타입, 메모리 사용량
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   Name         150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0       0.0
# ...

# %%
iris.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Name']
iris['Name']=iris['Name'].astype('int32')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0          5.1         3.5          1.4         0.2     0
# 1          4.9         3.0          1.4         0.2     0
# 2          4.7         3.2          1.3         0.2     0
# 3          4.6         3.1          1.5         0.2     0
# 4          5.0         3.6          1.4         0.2     0

# %%
import seaborn as sns
sns.pairplot(iris.iloc[:,:4],height=2)  # pairplot 변수 두개의 상관계수 보여줌

# %%
iris['sepal_ratio']=iris['SepalWidth']/iris['SepalLength']
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Name  sepal_ratio
# 0          5.1         3.5          1.4         0.2     0     0.686275
# 1          4.9         3.0          1.4         0.2     0     0.612245
# 2          4.7         3.2          1.3         0.2     0     0.680851
# 3          4.6         3.1          1.5         0.2     0     0.673913
# 4          5.0         3.6          1.4         0.2     0     0.720000

# %%
# chaining : optimization
(iris.query('SepalLength > 5')      # query => dataframe 에서 조건 설정시 사
        # 변수추가
        .assign(SepalRatio=lambda x: x.SepalWidth/x.SepalLength,
                PetalRatio=lambda x: x.PetalWidth/x.PetalLength)
        .plot(kind='scatter',x='SepalRatio',y='PetalRatio'))
        # 시각화
        #채이닝 치원
# Out:
# <Axes: xlabel='SepalRatio', ylabel='PetalRatio'>

# %%
#a.plot(kind='scatter', x='SepalRatio', y='petalRatio')

# %%
# 문제 :
#  Name':pd.Series(['김하나','이하나','삼하나','사하나','오하나', '육하나','칠하나', '팔하나']
#  'Age':pd.Series([25,26,25,23,30,29,23])
#  'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])

# 위 3가지 시리즈로 DF생성
# 데이터 타입을 확인
# 차원을 확인, 차수를 확인
# 전체 데이터 요소 사이즈를 확인
# 값들만 출력
data = {
    'Name': pd.Series(['김하나', '이하나', '삼하나', '사하나', '오하나', '육하나', '칠하나', '팔하나']),
    'Age': pd.Series([25, 26, 25, 23, 30, 29, 23]),
    'Rating': pd.Series([4.23, 3.24, 3.98, 2.56, 3.20, 4.6, 3.8])
}
data
# Out:
# {'Name': 0    김하나
#  1    이하나
#  2    삼하나
#  3    사하나
#  4    오하나
#  5    육하나
#  6    칠하나
#  7    팔하나
#  dtype: object,
#  'Age': 0    25
#  1    26
#  2    25
#  3    23
#  4    30
#  5    29
#  6    23
#  dtype: int64,
#  'Rating': 0    4.23
#  1    3.24
#  2    3.98
#  3    2.56
#  4    3.20
#  5    4.60
#  6    3.80
#  dtype: float64}

# %%
df=pd.DataFrame(data)
print(df.info())

print(df.dtypes)
print(df.shape)
print(df.ndim)
print(df.size)
print(df.values)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1610b8c05fcd> in <cell line: 1>()
# ----> 1 df=pd.DataFrame(data)
#       2 print(df.info())
#       3
#       4 print(df.dtypes)
#       5 print(df.shape)
#
# NameError: name 'pd' is not defined

# %%
print(df.axes)             # 행과 열 인덱스 확인
print('\n')
print(df.index)
print('\n')
print(df.columns)
print('\n')
print(df.empty)
print('\n')
print(df.head(3))
print(df.tail(2))
# Out:
# [RangeIndex(start=0, stop=8, step=1), Index(['Name', 'Age', 'Rating'], dtype='object')]
#
#
# RangeIndex(start=0, stop=8, step=1)
#
#
# Index(['Name', 'Age', 'Rating'], dtype='object')
#
#
# False
#
#
#   Name   Age  Rating
# 0  김하나  25.0    4.23
# 1  이하나  26.0    3.24
# 2  삼하나  25.0    3.98
#   Name   Age  Rating
# 6  칠하나  23.0     3.8
# 7  팔하나   NaN     NaN

# %%
# 열합계
print("합계",df.sum(axis=0))        # 수치 데이터만 적용
print('\n')
print("상관계수",df.corr())
print('\n')
print("평균",df.mean(axis=0))   # 열의 평균
print('\n')
print("표준편차",df.std(axis=0))
# Out:
# 합계 Name      김하나이하나삼하나사하나오하나육하나칠하나팔하나
# Age                          181.0
# Rating                       25.61
# dtype: object
#
#
# 상관계수              Age    Rating
# Age     1.000000  0.259006
# Rating  0.259006  1.000000
#
#
# 평균 Age       25.857143
# Rating     3.658571
# dtype: float64
#
#
# 표준편차 Age       2.734262
# Rating    0.698628
# dtype: float64
# <ipython-input-352-8e939d577d8f>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("상관계수",df.corr())
# <ipython-input-352-8e939d577d8f>:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("평균",df.mean(axis=0))
# ...

# %%
# 디폴트는 수치 데이터만 봄
print(df.describe())       # count, mean, std, min, 25%, 50% ,75%, max
# Out:
#              Age    Rating
# count   7.000000  7.000000
# mean   25.857143  3.658571
# std     2.734262  0.698628
# min    23.000000  2.560000
# 25%    24.000000  3.220000
# 50%    25.000000  3.800000
# 75%    27.500000  4.105000
# max    30.000000  4.600000

# %%
print("오브젝트",df.describe(include=['object']))
print('\n')
print(df.describe(include='all'))       # 전 필드에 대한 정보
# Out:
# 오브젝트        Name
# count     8
# unique    8
# top     김하나
# freq      1
#
#
#        Name        Age    Rating
# count     8   7.000000  7.000000
# unique    8        NaN       NaN
# top     김하나        NaN       NaN
# freq      1        NaN       NaN
# mean    NaN  25.857143  3.658571
# std     NaN   2.734262  0.698628
# min     NaN  23.000000  2.560000
# 25%     NaN  24.000000  3.220000
# 50%     NaN  25.000000  3.800000
# 75%     NaN  27.500000  4.105000
# max     NaN  30.000000  4.600000

# %%
# 문제 data = {'state':['경기','강원','서울','충북','인천],
#            'year':[2000,2001,2002,2001,2002],
#            'pop':[1.5.1.7.3.6.2.4.2.9]}
# 데이터 프레임으로 생성
# 행인덱스로 ['one','two','three','four','five']
# 2) status 만 출력
# 3) debt 열을추가 , 모둔 값을 16.5로
# 4) 파생변수 'estern' 에 주소가 서울인가를 따져 서울은 T, 아니면 F
# 5) debt 열에 대하여 (-1.2,-1.5,-1.7) index=['two','four','five']로 된 시리즈룰 만들고 대체하시오
# ^) 합꼐를 출력 (의미 있는 열에 대해서 합계)

# %%
data = {'state':(['경기','강원','서울','충북','인천']),
            'year':([2000,2001,2002,2001,2002]),
            'pop':([1.5,1.7,3.6,2.4,2.9])}
data
# Out:
# {'state': ['경기', '강원', '서울', '충북', '인천'],
#  'year': [2000, 2001, 2002, 2001, 2002],
#  'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}

# %%
dff=pd.DataFrame(data)
dff.index=['one','two','three','four','five']
dff['state']

dff['debt']=16.5
dff
# Out:
#       state  year  pop  debt
# one      경기  2000  1.5  16.5
# two      강원  2001  1.7  16.5
# three    서울  2002  3.6  16.5
# four     충북  2001  2.4  16.5
# five     인천  2002  2.9  16.5

# %%
# data.loc[data.density>100,['pop','density']]
# data.loc['Califonia','density']=90
# data
# 4) 파생변수 'estern' 에 주소가 서울인가를 따져 서울은 T, 아니면 F

#dff['estern']=np.where(dff.state=='서울',True,False)
dff['estern']=dff.state=='서울'
dff
# Out:
#       state  year  pop  debt  estern
# one      경기  2000  1.5   NaN   False
# two      강원  2001  1.7  -1.2   False
# three    서울  2002  3.6   NaN    True
# four     충북  2001  2.4  -1.5   False
# five     인천  2002  2.9  -1.7   False

# %%
# 5) debt 열에 대하여 (-1.2,-1.5,-1.7) index=['two','four','five']로 된 시리즈룰 만들고 대체하시오
val=pd.Series([-1.2,-1.5,-1.7],index=['two','four','five'])
dff['debt']=val
val
dff
# Out:
#       state  year  pop  debt  estern
# one      경기  2000  1.5   NaN   False
# two      강원  2001  1.7  -1.2   False
# three    서울  2002  3.6   NaN    True
# four     충북  2001  2.4  -1.5   False
# five     인천  2002  2.9  -1.7   False

# %%
# ^) 합계를 출력 (의미 있는 열에 대해서 합계)
dff.state.value_counts()        # 도수 분포표는 시리즈 데이터
# Out:
# 경기    1
# 강원    1
# 서울    1
# 충북    1
# 인천    1
# Name: state, dtype: int64

# %%
# 정렬
dff.state.sort_index()      # 인덱스 기준 정렬 state출력    ,키값에서 abc순으로 정렬되어있음
# Out:
# five     인천
# four     충북
# one      경기
# three    서울
# two      강원
# Name: state, dtype: object

# %%
dff.sort_values(['year'])       #연도기준 정렬
dff.sort_values(['year','pop'])
# Out:
#       state  year  pop  debt  estern
# one      경기  2000  1.5   NaN   False
# two      강원  2001  1.7  -1.2   False
# four     충북  2001  2.4  -1.5   False
# three    서울  2002  3.6   NaN    True
# five     인천  2002  2.9  -1.7   False

# %%
dff.sort_index()    #인덱스 기준
# Out:
#       state  year  pop  debt  estern
# five     인천  2002  2.9  -1.7   False
# four     충북  2001  2.4  -1.5   False
# one      경기  2000  1.5   NaN   False
# three    서울  2002  3.6   NaN    True
# two      강원  2001  1.7  -1.2   False

# %%
print(dff[['pop','debt']].sum(axis=0))  # pop,debt에 대한 열 합
print('\n')
print(dff.describe(include='all'))  # 모든 정보
dff.state.value_counts()        # 도수분포표는 시리즈 데이터
# Out:
# pop     12.1
# debt    -4.4
# dtype: float64
#
#
#        state        year       pop      debt estern
# count      5     5.00000  5.000000  3.000000      5
# unique     5         NaN       NaN       NaN      2
# top       경기         NaN       NaN       NaN  False
# freq       1         NaN       NaN       NaN      4
# mean     NaN  2001.20000  2.420000 -1.466667    NaN
# std      NaN     0.83666  0.864292  0.251661    NaN
# min      NaN  2000.00000  1.500000 -1.700000    NaN
# 25%      NaN  2001.00000  1.700000 -1.600000    NaN
# 50%      NaN  2001.00000  2.400000 -1.500000    NaN
# 75%      NaN  2002.00000  2.900000 -1.350000    NaN
# max      NaN  2002.00000  3.600000 -1.200000    NaN
# 경기    1
# 강원    1
# 서울    1
# 충북    1
# 인천    1
# Name: state, dtype: int64

# %%
# 시간 인덱스
# 판다스나 넘파이는 ns(나노초)를 지원
# python core는 mm초를 지원
# 시계열 데이터 표현
df= pd.DataFrame({"y":[1,2,3]},
                 index=pd.to_datetime(['2000-03-31 00:00:00',   # to_datetime 문자열을 시계열로
                                       '2000-05-31 00:00:00',
                                       '2000-08-31 00:00:00']))
print(df)
print('\n')
print(df.axes)      # 열에대한 속성
df.index=df.index.to_period('M')   # Month
print(df)   #날짜는 사라지고 월까지만 남음
# Out:
#             y
# 2000-03-31  1
# 2000-05-31  2
# 2000-08-31  3
#
#
# [DatetimeIndex(['2000-03-31', '2000-05-31', '2000-08-31'], dtype='datetime64[ns]', freq=None), Index(['y'], dtype='object')]
#          y
# 2000-03  1
# 2000-05  2
# 2000-08  3

# %%
import matplotlib.pyplot as plt

data=np.random.randn(25,4)
df=pd.DataFrame(data,columns=list('ABCD'))
print(df)
ax=df.plot.box()
plt.show()
df.to_pickle("./data.pkl")      # 저장, 메모리에 있는 내용을 그대로 저장(2진수로)
df=pd.read_pickle("./data.pkl")     # 로딩
df.head()
# Out:
#            A         B         C         D
# 0   2.321192 -2.279818 -1.168830  1.416011
# 1  -0.596994  0.207241  2.328382 -0.467158
# 2   0.478433 -0.693062 -0.218115 -1.385947
# 3  -1.620210 -1.703475 -0.355223 -1.153097
# 4   0.401699  0.036015 -0.780493  0.401954
# 5  -1.819149 -0.399599 -1.093640  0.752210
# 6   0.126019  0.786844  0.467047 -0.546327
# 7   1.639321  0.124847  0.384739 -1.293768
# 8   0.347799 -1.020191 -0.131640  0.002286
# 9   0.344231 -0.923917 -0.076667  0.820887
# 10  0.318812 -0.166361  0.515472 -1.515258
# 11  0.652759 -0.356459  0.916943 -1.346712
# 12 -1.290451 -0.199975 -0.001026 -0.408099
# 13  0.720140  1.455553 -1.304113  2.016869
# 14  0.141272  0.806485  0.485555  1.756964
# 15  0.306723 -1.128567 -1.002940  1.373716
# 16 -0.942138 -2.098195  0.789958  0.390007
# 17  1.776869 -0.292177  0.476338  0.041647
# 18  1.746674  0.018967  1.006307  1.322929
# 19  0.849334  1.918549  0.441921 -1.925302
# 20  0.599973  0.468876  1.219495  0.634435
# ...

# %%
data = {'name': ['하늘이', '찬호박', '우리야', '함께가', '하성공'],
'age': [40, 50, 30, 20, 70],
'preScore': [14, 28, 39, 25, 32],
'postScore': [20, 90, 55, 65, 79]}
df = pd.DataFrame(data,columns = ['name', 'age', 'preScore', 'postScore'])
df
# Out:
#   name  age  preScore  postScore
# 0  하늘이   40        14         20
# 1  찬호박   50        28         90
# 2  우리야   30        39         55
# 3  함께가   20        25         65
# 4  하성공   70        32         79

# %%
print(df['age'].sum())
print(df['preScore'].mean())
print(df['preScore'].cumsum())
print(df['preScore'].describe())
print(df['preScore'].var())
print(df['preScore'].std())
print('\n')
print(df['preScore'].skew())    #왜도 : 좌우대징 기준 0
print(df['preScore'].kurt())    #첨도 : 뾰족함 정도 기준 3

print(df.cov())     #공분산
print(df.corr())
# Out:
# 210
# 27.6
# 0     14
# 1     42
# 2     81
# 3    106
# 4    138
# Name: preScore, dtype: int64
# count     5.0000
# mean     27.6000
# std       9.2358
# min      14.0000
# 25%      25.0000
# 50%      28.0000
# 75%      32.0000
# max      39.0000
# Name: preScore, dtype: float64
# 85.30000000000001
# 9.235799911215056
#
#
# -0.5110345040062979
# 0.8509652849263816
#              age  preScore  postScore
# age        370.0      18.5      200.5
# preScore    18.5      85.3      142.4
# postScore  200.5     142.4      723.7
#                 age  preScore  postScore
# age        1.000000  0.104135   0.387467
# preScore   0.104135  1.000000   0.573134
# postScore  0.387467  0.573134   1.000000
# <ipython-input-371-942f4e43060f>:11: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.cov())     #공분산
# ...

# %%
# 판다스는 열중심
print(np.cov(df[['age','preScore','postScore']].T)) # 전치해줌, 넘파이는 행중심이어서
print('\n')
print(np.corrcoef(df[['age','preScore','postScore']].T))
# Out:
# [[370.   18.5 200.5]
#  [ 18.5  85.3 142.4]
#  [200.5 142.4 723.7]]
#
#
# [[1.         0.10413491 0.38746656]
#  [0.10413491 1.         0.57313402]
#  [0.38746656 0.57313402 1.        ]]

# %%
# 데이터를 데이터 프레임에 입력하고
#                    지역    2018      2017    2016     2015    2015-2018 증가율    <=col 이름
data = {"서울" : ["수도권", 9904312, 9631482, 9762546, 9853972, 0.0283],
        "부산" : ["경상권", 3448737, 3393191, 3512547, 3655437, 0.0163],
        "인천" : ["수도권", 2890451, 2632035, 2517680, 2466338, 0.0982],
        "대구" : ["경상권", 2466052, 2431774, 2456016, 2473990, 0.0141]}
data

df=pd.DataFrame(data)
#df.index=['지역','2018','2017','2016','2015','2015-2018 증가율']
columns=['지역','2018','2017','2016','2015','2015-2018 증가율']
df = pd.DataFrame(data, index=columns)
df=df.T
#df = pd.DataFrame(data,columns = ['지역','2018','2017','2016','2015','2015-2018 증가율'])
df
# Out:
#      지역     2018     2017     2016     2015 2015-2018 증가율
# 서울  수도권  9904312  9631482  9762546  9853972        0.0283
# 부산  경상권  3448737  3393191  3512547  3655437        0.0163
# 인천  수도권  2890451  2632035  2517680  2466338        0.0982
# 대구  경상권  2466052  2431774  2456016  2473990        0.0141

# %%
# 2015~2017 증가율을 %로 변경하시오
# 소수점 3번쨰자리에서 반올림 2번째 표현
# 증가율을 구해서 변수로 추가 %
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 서울 to 대구
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             4 non-null      object
#  1   2018           4 non-null      object
#  2   2017           4 non-null      object
#  3   2016           4 non-null      object
#  4   2015           4 non-null      object
#  5   2015-2018 증가율  4 non-null      object
# dtypes: object(6)
# memory usage: 224.0+ bytes

# %%
df['2015-2018 증가율']=df['2015-2018 증가율']*100

# %%
df['2015']=df['2015'].astype('float')
df['2016']=df['2016'].astype('float')
df['2017']=df['2017'].astype('float')
df['2018']=df['2018'].astype('float')
df['2015-2018 증가율'].astype('float')
df["2015-2017증가율"]=((df['2017']-df['2015'])/df['2015']*100).round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 서울 to 대구
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지역             4 non-null      object
#  1   2018           4 non-null      float64
#  2   2017           4 non-null      float64
#  3   2016           4 non-null      float64
#  4   2015           4 non-null      float64
#  5   2015-2018 증가율  4 non-null      object
#  6   2015-2017증가율   4 non-null      float64
# dtypes: float64(5), object(2)
# memory usage: 256.0+ bytes

# %%
# 계층적 인덱스
index = [('California', 2000), ('California', 2010),
         ('New York', 2000), ('New York', 2010),
         ('Texas', 2000), ('Texas', 2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]
pop=pd.Series(populations, index=index)
pop
# Out:
# (California, 2000)    33871648
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# (Texas, 2010)         25145561
# dtype: int64

# %%
pop.index
# Out:
# Index([('California', 2000), ('California', 2010),   ('New York', 2000),
#          ('New York', 2010),      ('Texas', 2000),      ('Texas', 2010)],
#       dtype='object')

# %%
pop[('California',2010):('Texas',2000)] # 그냥은 문자열로 인식
# Out:
# (California, 2010)    37253956
# (New York, 2000)      18976457
# (New York, 2010)      19378102
# (Texas, 2000)         20851820
# dtype: int64

# %%
index=pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )

# %%
pop=pop.reindex(index)
pop
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop[:,2010]
# stacking  인덱스가 쌓여있다
# Out:
# California    37253956
# New York      19378102
# Texas         25145561
# dtype: int64

# %%
pop_df=pop.unstack()        # 풀어줌
pop_df
# Out:
#                 2000      2010
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop_df.stack()
# Out:
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
# 멀티 인덱스를 가진 데이터가 데이터 프레임으로 입력될 때 유지
pop_df=pd.DataFrame({'total':pop,
                     'under18':[1,2,
                                3,4,
                                5,6]})
pop_df
# Out:
#                     total  under18
# California 2000  33871648        1
#            2010  37253956        2
# New York   2000  18976457        3
#            2010  19378102        4
# Texas      2000  20851820        5
#            2010  25145561        6

# %%
# 데이터에 함수 적용하기(apply: 열별로 적용, applymap: 열별 요소별로 적용, map:시리즈)

# %%
Sample={'Value':[5.52132,6.572935,7.21,8.755,9.9989]}
df=pd.DataFrame(Sample, columns=['Value'])

print(df)
print('\n')
# numpy np.math.round , np.round
df['Value'].round(decimals=3)   # chaining 으로 함수 적용
roundThree=np.round(df['Value'],decimals=3)
print(roundThree)
print('올림',df['Value'].apply(np.ceil))    # 함수만 전달
df['Value'].apply(np.floor)
# Out:
#       Value
# 0  5.521320
# 1  6.572935
# 2  7.210000
# 3  8.755000
# 4  9.998900
#
#
# 0    5.521
# 1    6.573
# 2    7.210
# 3    8.755
# 4    9.999
# Name: Value, dtype: float64
# 올림 0     6.0
# 1     7.0
# 2     8.0
# 3     9.0
# 4    10.0
# Name: Value, dtype: float64
# 0    5.0
# 1    6.0
# 2    7.0
# 3    8.0
# 4    9.0
# Name: Value, dtype: float64

# %%
frame=pd.DataFrame((np.random.randn(4,3)),columns=list(['rain','income','tax']), index=['seoul','daejun','incheon','daegu'])
print(frame)
print("absolute 함수적용",np.abs(frame))
print('\n')
print(frame.apply(np.ptp,axis=0))   # 함수의 주소 전달
print('\n')
print(frame.apply(np.ptp,axis=1))

f = lambda x: x.max()-x.min()
print("함수 객체의 행 적용 ( 열방향)", "\n",frame.apply(f, axis=0))
print("함숫 객체 열 적용(행방량)",frame.apply(f,axis=1))
# Out:
#              rain    income       tax
# seoul   -0.437401 -0.354006  1.684872
# daejun   0.153180  0.556626  0.549674
# incheon -0.661681  1.623767  0.248033
# daegu    0.800338 -2.821006  0.122998
# absolute 함수적용              rain    income       tax
# seoul    0.437401  0.354006  1.684872
# daejun   0.153180  0.556626  0.549674
# incheon  0.661681  1.623767  0.248033
# daegu    0.800338  2.821006  0.122998
#
#
# rain      1.462019
# income    4.444773
# tax       1.561874
# dtype: float64
#
#
# seoul      2.122273
# daejun     0.403446
# incheon    2.285448
# daegu      3.621344
# dtype: float64
# 함수 객체의 행 적용 ( 열방향)
#  rain      1.462019
# income    4.444773
# tax       1.561874
# dtype: float64
# 함숫 객체 열 적용(행방량) seoul      2.122273
# daejun     0.403446
# incheon    2.285448
# daegu      3.621344
# dtype: float64

# %%
def f(x):   # 열별로 받아서 처리(Series로 보고 처리)
    return pd.Series([x.min(),x.max()],index=['min','max'])
    print('함숫 객체 적용',frame.apply(f))

# %%
format=lambda x: '%.2f' %x  # 개별적요소, 열별 요소별로
print(frame.applymap(format))
# Out:
#           rain income    tax
# seoul    -1.04  -1.28  -0.34
# daejun    1.76  -1.26   0.46
# incheon  -1.12  -0.35   0.42
# daegu     0.12  -1.02  -0.36

# %%
print(frame['rain'].map(format)) # 시리즈에 적용
# Out:
# seoul      -1.04
# daejun      1.76
# incheon    -1.12
# daegu       0.12
# Name: rain, dtype: object

# %%
# python core + pandas

# %% [markdown]
# 이름 국어 영어 수학 점수 3인분을 입력받아서
#
# 데이터 프레임으로 변환하고
#
# 합계와 평균을 구하시오 ( 과목별, 학색별 apply 적용)
#
# 데이터 프레임을 합계를 기죽을 정렬을 하고 등수를 입력
#
# 과목별 분산과 표준편차를 구하시오 (apply적용)
#
# 과목별 상관계수와 공분산을 구하시오

# %%
students=[]
name=[]
for i in range(3):
    student=input('이름, 국, 영, 수  입력:')
    students.append(student.split(',')[1:])
    name.append(student.split(',')[0])
# Out:
# 이름, 국, 영, 수  입력:박,100,100,90
# 이름, 국, 영, 수  입력:지,70,60,70
# 이름, 국, 영, 수  입력:운,90,80,100

# %%
# to_numeric 에러처리방법( ignore, raise, coerce 강제적 변경)

# %%
data=pd.DataFrame(students,columns=['국어','영어','수학'],index=name)
data['국어']=pd.to_numeric(data['국어'])
data['영어']=pd.to_numeric(data['영어'])
data['수학']=pd.to_numeric(data['수학'])

# %%
data['합계']=data.iloc[:,:3].apply(lambda x : x.sum(), axis=1)
data
# Out:
#     국어   영어   수학   합계
# 박  100  100   90  290
# 지   70   60   70  200
# 운   90   80  100  270

# %%
data['평균']=data.iloc[:,:3].apply(lambda x: x.mean(),axis=1).round(1)

# %%
data
# Out:
#     국어   영어   수학   합계    평균
# 박  100  100   90  290  96.7
# 지   70   60   70  200  66.7
# 운   90   80  100  270  90.0

# %%
result=data.sort_values(by=['합계'],axis=0,ascending=False)
ser = pd.Series(np.arange(len(data))+1,index=result.index)
print(ser)
data['등수']=ser
data
# Out:
# 박    1
# 운    2
# 지    3
# dtype: int64
#     국어   영어   수학   합계    평균  등수
# 박  100  100   90  290  96.7   1
# 지   70   60   70  200  66.7   3
# 운   90   80  100  270  90.0   2

# %%
result.iloc[:,:3].apply(lambda x:x.var(),axis=0)    # 열별
# Out:
# 국어    233.333333
# 영어    400.000000
# 수학    233.333333
# dtype: float64

# %%
result.iloc[:,:3].apply(lambda x: x.std(),axis=0)
# Out:
# 국어    15.275252
# 영어    20.000000
# 수학    15.275252
# dtype: float64

# %%
result.iloc[:,:3].cov()
# Out:
#             국어     영어          수학
# 국어  233.333333  300.0  183.333333
# 영어  300.000000  400.0  200.000000
# 수학  183.333333  200.0  233.333333

# %%
result.iloc[:,:3].corr()
# Out:
#           국어        영어        수학
# 국어  1.000000  0.981981  0.785714
# 영어  0.981981  1.000000  0.654654
# 수학  0.785714  0.654654  1.000000

# %%
# matplotlib 는 한글 지원 x
# colab 에서만
import matplotlib.pyplot as plt

# !apt-get update -qq
# !apt-get fonts-nanum* -qq
import matplotlib.font_manager as fm
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumGothuc.ttf',
    name='NanumGothic')
fm.fontManager.ttflist.insert(0,fe)
plt.rcParams.update({'font.size':18,'font.family':'NanumGothic'})
# Out:
# E: Invalid operation fonts-nanum*

# %%
sns.pairplot(data.iloc[:,:3])
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
cor1=data.iloc[:,:3].corr()
cor1.style.background_gradient(cmap='coolwarm').set_precision(2)    # 2째 자리까지 표현
# Out:
# <ipython-input-272-bf75c715b001>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   cor1.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_e26a9_row0_col0, #T_e26a9_row1_col1, #T_e26a9_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e26a9_row0_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_e26a9_row0_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e26a9_row1_col0 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_e26a9_row1_col2, #T_e26a9_row2_col0, #T_e26a9_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e26a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e26a9_level0_col0" class="col_heading level0 col0" >국어</th>
#       <th id="T_e26a9_level0_col1" class="col_heading level0 col1" >영어</th>
# ...

# %%
# 데이터 베이스에서 데이터 가져오기
# db 에서 가져온 데이터는 리스트

# %%
# colab

# !pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pymysql
conn= pymysql.connect(host='34.64.175.131',port=3306,user='root',
                      passwd='Qkrwldns!5',db='sungjuk',charest='utf8mb4',
                      cursorclass=pymysql.cursors.DictCursor)
cursor=conn.corsor()        # 클라인언트 커서, 데이터 가리킨것
cursor.execute('select * from student')
rez=cursor.ferchall()       # 모든 데이터를 python core로
print("페치의 데이터 타입",type(rez))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-388-a31fd238f4cf> in <cell line: 2>()
#       1 import pymysql
# ----> 2 conn= pymysql.connect(host='34.64.175.131',port=3306,user='root',
#       3                       passwd='Qkrwldns!5',db='sungjuk',charest='utf8mb4',
#       4                       cursorclass=pymysql.cursors.DictCursor)
#       5 cursor=conn.corsor()        # 클라인언트 커서, 데이터 가리킨것
#
# TypeError: Connection.__init__() got an unexpected keyword argument 'charest'

# %%
df=pd.DataFrame(rez)
print(df.describe())
print(df.dtypes)
print(df.shape)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-387-cedc69294d64> in <cell line: 1>()
# ----> 1 df=pd.DataFrame(rez)
#       2 print(df.describe())
#       3 print(df.dtypes)
#       4 print(df.shape)
#       5 df
#
# NameError: name 'rez' is not defined
